# %%
from Application import C64

c64 = C64()
c64.start()
# Out:
# initialisation de couleur échoué
# RangeFinder instantiate
# Remote Control instantiate
# Camera Servo instantiate
# RangeFinder instantiate
# Robot integrity test has succeeded
# 9207.335038413
# Home, prêt à écouter votre commande...
# Tâche 1 en cours
# in tâche 1
# in tâche 1
# in tâche 1
# in tâche 1
# in tâche 1
# in tâche 1
# in tâche 1
# in tâche 1
# in tâche 1
# in tâche 1
# in tâche 1
# in tâche 1
# in tâche 1
# in tâche 1
# in tâche 1
# in tâche 1
# in tâche 1
# in tâche 1
# in tâche 1
# in tâche 1
# in tâche 1
# in tâche 1
# in tâche 1
# in tâche 1
# in tâche 1
# in tâche 1
# in tâche 1
# in tâche 1
# in tâche 1
# in tâche 1
# in tâche 1
# in tâche 1
# in tâche 1
# in tâche 1
# in tâche 1
# in tâche 1
# in tâche 1
# in tâche 1
# in tâche 1
# in tâche 1
# in tâche 1
# in tâche 1
# in tâche 1
# in tâche 1
# in tâche 1
# in tâche 1
# in tâche 1
# in tâche 1
# in tâche 1
# in tâche 1
# in tâche 1
# in tâche 1
# in tâche 1
# in tâche 1
# in tâche 1
# in tâche 1
# in tâche 1
# ...
